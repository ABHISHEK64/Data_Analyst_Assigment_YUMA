# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r'C:\Users\abhis\Documents\yuma_assignment\yuma_sales_transactions.csv')
df.head()
# Out:
#    TransactionID  CustomerID TransactionDate Trasaction Time  ProductID  \
# 0              1      1002.0      08-08-2024        22:00:00       2008
# 1              2         NaN      07-08-2024        01:00:00       2004
# 2              3      1004.0      02-08-2024        19:00:00       2002
# 3              2      1003.0      07-08-2024        17:00:00       2001
# 4              5      1001.0      09-08-2024        09:00:00       2008
#
#   ProductCategory  Quantity  PricePerUnit  TotalAmount  TrustPointsUsed  \
# 0         Grocery         1          10.0         10.0               20
# 1      Home Decor         1          10.0         10.0                0
# 2         Grocery         3          30.0         90.0                0
# 3            Toys         2          30.0         60.0               50
# 4         Grocery         1           NaN          NaN               20
#
#   PaymentMethod  DiscountApplied
# 0  Trust Points              5.0
# 1   Credit Card             20.0
# 2   Credit Card             25.0
# 3           NaN             20.0
# 4  Trust Points              5.0

# %%
df['ProductCategory'].value_counts()
# Out:
# ProductCategory
# Toys           13
# Electronics    13
# Home Decor     10
# Grocery         8
# Fashion         6
# Name: count, dtype: int64

# %%
df['PaymentMethod'].unique()
# Out:
# array(['Trust Points', 'Credit Card', nan, 'Cash'], dtype=object)

# %%
df.isna().sum()
# Out:
# TransactionID       0
# CustomerID          5
# TransactionDate     1
# Trasaction Time     1
# ProductID           0
# ProductCategory     0
# Quantity            0
# PricePerUnit       14
# TotalAmount        14
# TrustPointsUsed     0
# PaymentMethod      10
# DiscountApplied     5
# dtype: int64

# %%
### As we have checked that Total Amount and price per unit price is both null there nothing we can do so we have scrap
df[df['TotalAmount'].isna()==True]
# Out:
#     TransactionID  CustomerID TransactionDate Trasaction Time  ProductID  \
# 4               5      1001.0      09-08-2024        09:00:00       2008
# 5               6      1001.0             NaN             NaN       2007
# 8               9      1004.0      02-08-2024        23:00:00       2008
# 10             11      1001.0      09-08-2024        07:00:00       2003
# 12             13      1005.0      09-08-2024        22:00:00       2008
# 16             17      1002.0      09-08-2024        15:00:00       2001
# 19             20      1002.0      03-08-2024        04:00:00       2007
# 23             24      1002.0      08-08-2024        19:00:00       2005
# 30             31      1004.0      04-08-2024        16:00:00       2001
# 36             37      1002.0      09-08-2024        23:00:00       2005
# 45             46      1004.0      01-08-2024        04:00:00       2004
# 47             48      1003.0      02-08-2024        03:00:00       2005
# 48             49      1003.0      06-08-2024        14:00:00       2007
# 49             50      1001.0      09-08-2024        08:00:00       2007
#
#    ProductCategory  Quantity  PricePerUnit  TotalAmount  TrustPointsUsed  \
# 4          Grocery         1           NaN          NaN               20
# 5       Home Decor         1           NaN          NaN               20
# 8          Fashion         1           NaN          NaN              -10
# 10         Grocery         5           NaN          NaN              -10
# 12         Grocery         3           NaN          NaN              100
# 16            Toys         1           NaN          NaN               20
# 19         Fashion         2           NaN          NaN              -10
# 23     Electronics         1           NaN          NaN              100
# 30      Home Decor         3           NaN          NaN                0
# 36         Fashion         1           NaN          NaN              100
# 45            Toys         1           NaN          NaN              100
# 47      Home Decor         0           NaN          NaN               50
# 48     Electronics        -1           NaN          NaN                0
# 49         Grocery         3           NaN          NaN               50
#
#    PaymentMethod  DiscountApplied
# 4   Trust Points              5.0
# 5    Credit Card              NaN
# 8            NaN              NaN
# 10   Credit Card             20.0
# 12  Trust Points             50.0
# 16           NaN             10.0
# 19          Cash             50.0
# 23  Trust Points             10.0
# 30   Credit Card             30.0
# 36           NaN             30.0
# 45           NaN             20.0
# 47           NaN             50.0
# 48          Cash             20.0
# 49  Trust Points             30.0

# %%
df1=df[df['TotalAmount'].isna()==False]

# %%
## fixing payment methord
df1['PaymentMethod'] = np.where(df1['Quantity'] <= -1, 'Return', df1['PaymentMethod'])
df1[df1['Quantity']<=-1]
# Out:
# C:\Users\abhis\AppData\Local\Temp\ipykernel_15316\352294960.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['PaymentMethod'] = np.where(df1['Quantity'] <= -1, 'Return', df1['PaymentMethod'])
#     TransactionID  CustomerID TransactionDate Trasaction Time  ProductID  \
# 6               7      1001.0      2024-08-01        13:00:00       2007
# 34             35      1001.0      2024-08-06        08:00:00       2002
# 38             39      1004.0      2024-08-06        18:00:00       2007
#
#    ProductCategory  Quantity  PricePerUnit  TotalAmount  TrustPointsUsed  \
# 6       Home Decor        -1          30.0        -30.0              -10
# 34     Electronics        -1         500.0       -500.0              100
# 38      Home Decor        -1          10.0        -10.0               20
#
#    PaymentMethod  DiscountApplied
# 6         Return              NaN
# 34        Return             30.0
# 38        Return             20.0

# %%
df1['CustomerID'].fillna(df1['CustomerID'].mode()[0], inplace=True)
df1['CustomerID'] = np.where(df1['ProductCategory'] == 'Electronics', 
                             df1['CustomerID'], 
                             df1['CustomerID'])
df1[df1['ProductCategory'] == 'Home Decor']
# Out:
# C:\Users\abhis\AppData\Local\Temp\ipykernel_15316\1855841639.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['CustomerID'].fillna(df1['CustomerID'].mode()[0], inplace=True)
# C:\Users\abhis\AppData\Local\Temp\ipykernel_15316\1855841639.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['CustomerID'] = np.where(df1['ProductCategory'] == 'Electronics',
#     TransactionID  CustomerID TransactionDate Trasaction Time  ProductID  \
# 1               2      1001.0      2024-08-07        01:00:00       2004
# 6               7      1001.0      2024-08-01        13:00:00       2007
# 18             19      1003.0      2024-08-05        14:00:00       2005
# 25             26      1004.0      2024-08-02        16:00:00       2007
# 31             32      1001.0      2024-08-03        22:00:00       2007
# 35             36      1005.0      2024-08-06        15:00:00       2004
# 38             39      1004.0      2024-08-06        18:00:00       2007
#
#    ProductCategory  Quantity  PricePerUnit  TotalAmount  TrustPointsUsed  \
# 1       Home Decor         1          10.0         10.0                0
# 6       Home Decor        -1          30.0        -30.0              -10
# 18      Home Decor         3         500.0       1500.0              100
# 25      Home Decor         2          10.0         20.0              100
# 31      Home Decor         1         500.0        500.0               50
# 35      Home Decor         1          30.0         30.0              -10
# 38      Home Decor        -1          10.0        -10.0               20
#
#    PaymentMethod  DiscountApplied
# 1    Credit Card             20.0
# 6         Return              NaN
# 18          Cash             50.0
# 25  Trust Points             30.0
# 31          Cash              5.0
# 35          Cash             50.0
# 38        Return             20.0

# %%
df1['PaymentMethod'].fillna(df1['PaymentMethod'].mode()[0], inplace=True)
# Out:
# C:\Users\abhis\AppData\Local\Temp\ipykernel_15316\2453949572.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['PaymentMethod'].fillna(df1['PaymentMethod'].mode()[0], inplace=True)

# %%
df1['PaymentMethod'].value_counts()
# Out:
# PaymentMethod
# Cash            18
# Trust Points     9
# Credit Card      6
# Return           3
# Name: count, dtype: int64

# %%
## Converting Dates from DD-MM-YYYY to yyyy-mm-dd format
df['TransactionDate'] = pd.to_datetime(df['TransactionDate'], format="%d-%m-%Y")

df1['TransactionDate'] = df['TransactionDate'].dt.strftime("%Y-%m-%d")
# Out:
# C:\Users\abhis\AppData\Local\Temp\ipykernel_15316\372944490.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['TransactionDate'] = df['TransactionDate'].dt.strftime("%Y-%m-%d")

# %%
df1['DiscountApplied'].fillna(0,inplace=True)
df1.head()
# Out:
# C:\Users\abhis\AppData\Local\Temp\ipykernel_15316\3049835226.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['DiscountApplied'].fillna(0,inplace=True)
#    TransactionID  CustomerID TransactionDate Trasaction Time  ProductID  \
# 0              1      1002.0      2024-08-08        22:00:00       2008
# 1              2      1001.0      2024-08-07        01:00:00       2004
# 2              3      1004.0      2024-08-02        19:00:00       2002
# 3              2      1003.0      2024-08-07        17:00:00       2001
# 6              7      1001.0      2024-08-01        13:00:00       2007
#
#   ProductCategory  Quantity  PricePerUnit  TotalAmount  TrustPointsUsed  \
# 0         Grocery         1          10.0         10.0               20
# 1      Home Decor         1          10.0         10.0                0
# 2         Grocery         3          30.0         90.0                0
# 3            Toys         2          30.0         60.0               50
# 6      Home Decor        -1          30.0        -30.0              -10
#
#   PaymentMethod  DiscountApplied
# 0  Trust Points              5.0
# 1   Credit Card             20.0
# 2   Credit Card             25.0
# 3          Cash             20.0
# 6        Return              0.0

# %%
df1.to_csv('clean_data.csv', index=True)

# %%
df1.head()
# Out:
#    TransactionID  CustomerID TransactionDate Trasaction Time  ProductID  \
# 0              1      1002.0      2024-08-08        22:00:00       2008
# 1              2      1001.0      2024-08-07        01:00:00       2004
# 2              3      1004.0      2024-08-02        19:00:00       2002
# 3              2      1003.0      2024-08-07        17:00:00       2001
# 6              7      1001.0      2024-08-01        13:00:00       2007
#
#   ProductCategory  Quantity  PricePerUnit  TotalAmount  TrustPointsUsed  \
# 0         Grocery         1          10.0         10.0               20
# 1      Home Decor         1          10.0         10.0                0
# 2         Grocery         3          30.0         90.0                0
# 3            Toys         2          30.0         60.0               50
# 6      Home Decor        -1          30.0        -30.0              -10
#
#   PaymentMethod  DiscountApplied
# 0  Trust Points              5.0
# 1   Credit Card             20.0
# 2   Credit Card             25.0
# 3          Cash             20.0
# 6        Return              NaN
